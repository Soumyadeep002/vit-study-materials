# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('opsd_germany_daily.csv')
df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
df["Date"] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Consumption  Wind  Solar  Wind+Solar
# 0 2006-01-01     1069.184   NaN    NaN         NaN
# 1 2006-01-02     1380.521   NaN    NaN         NaN
# 2 2006-01-03     1442.533   NaN    NaN         NaN
# 3 2006-01-04     1457.217   NaN    NaN         NaN
# 4 2006-01-05     1477.131   NaN    NaN         NaN

# %%
df = df.set_index(df['Date'])
df = df.drop(['Date'], axis=1)
df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
plt.figure(figsize=(18, 4))
df["Consumption"].plot(linewidth=0.4, alpha=0.6)
plt.show()

# %%
cols_to_plot = ['Consumption', 'Solar', 'Wind']
axes = df[cols_to_plot].dropna().plot(alpha=0.5,figsize=(14, 7), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

# %%
df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.index.year.unique()
# Out:
# Index([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], dtype='int32', name='Date')

# %%
df.loc['2016-01-01':'2016-02-01'].plot(kind="box")
# Out:
# <Axes: >

# %%
ls = ["A", "C", "D"]

for i, j in enumerate(ls):
    print(f"{i} : {j}")
# Out:
# 0 : A
# 1 : C
# 2 : D

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 5))
sns.histplot(df["Consumption"], kde=True, alpha= 0.2, ax=ax[0])
sns.histplot(df["Solar"], kde=True, alpha= 0.2, ax=ax[1])
sns.histplot(df["Wind"], kde=True, alpha= 0.2, ax=ax[2])
# Out:
# <Axes: xlabel='Wind', ylabel='Count'>
