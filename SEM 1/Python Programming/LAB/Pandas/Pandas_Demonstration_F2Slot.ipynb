# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(10,80,size=(5,6)),\
index = ['R'+str(i+1) for i in range(5)],\
columns = ['C'+str(i+1) for i in range(6)])
df['Name'] = ['A','B','C','D','E']

# %%
df
# Out:
#     C1  C2  C3  C4  C5  C6 Name
# R1  63  39  26  31  39  72    A
# R2  73  50  35  53  44  53    B
# R3  41  12  76  31  44  10    C
# R4  39  56  47  57  57  41    D
# R5  62  40  21  12  12  58    E

# %%
for col,val in df.items():
    print(col,val)
    print(type(col),type(val))
# Out:
# C1 R1    63
# R2    73
# R3    41
# R4    39
# R5    62
# Name: C1, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C2 R1    39
# R2    50
# R3    12
# R4    56
# R5    40
# Name: C2, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C3 R1    26
# R2    35
# R3    76
# R4    47
# R5    21
# Name: C3, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C4 R1    31
# R2    53
# R3    31
# R4    57
# R5    12
# Name: C4, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C5 R1    39
# R2    44
# R3    44
# R4    57
# R5    12
# Name: C5, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# C6 R1    72
# R2    53
# R3    10
# R4    41
# R5    58
# Name: C6, dtype: int32
# <class 'str'> <class 'pandas.core.series.Series'>
# Name R1    A
# R2    B
# R3    C
# R4    D
# R5    E
# Name: Name, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>

# %%
for row,val in df.iterrows():
    print(row,val)
    print(type(row),type(val))
# Out:
# R1 C1      63
# C2      39
# C3      26
# C4      31
# C5      39
# C6      72
# Name     A
# Name: R1, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R2 C1      73
# C2      50
# C3      35
# C4      53
# C5      44
# C6      53
# Name     B
# Name: R2, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R3 C1      41
# C2      12
# C3      76
# C4      31
# C5      44
# C6      10
# Name     C
# Name: R3, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R4 C1      39
# C2      56
# C3      47
# C4      57
# C5      57
# C6      41
# Name     D
# Name: R4, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>
# R5 C1      62
# C2      40
# C3      21
# C4      12
# C5      12
# C6      58
# Name     E
# Name: R5, dtype: object
# <class 'str'> <class 'pandas.core.series.Series'>

# %%
for t in df.itertuples():
    print(t)
    print(type(t))
# Out:
# Pandas(Index='R1', C1=63, C2=39, C3=26, C4=31, C5=39, C6=72, Name='A')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R2', C1=73, C2=50, C3=35, C4=53, C5=44, C6=53, Name='B')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R3', C1=41, C2=12, C3=76, C4=31, C5=44, C6=10, Name='C')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R4', C1=39, C2=56, C3=47, C4=57, C5=57, C6=41, Name='D')
# <class 'pandas.core.frame.Pandas'>
# Pandas(Index='R5', C1=62, C2=40, C3=21, C4=12, C5=12, C6=58, Name='E')
# <class 'pandas.core.frame.Pandas'>

# %%
df
# Out:
#     C1  C2  C3  C4  C5  C6 Name
# R1  63  39  26  31  39  72    A
# R2  73  50  35  53  44  53    B
# R3  41  12  76  31  44  10    C
# R4  39  56  47  57  57  41    D
# R5  62  40  21  12  12  58    E

# %%
df.index
# Out:
# Index(['R1', 'R2', 'R3', 'R4', 'R5'], dtype='object')

# %%
df.columns
# Out:
# Index(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'Name'], dtype='object')

# %%
df.index = ['R1','R2','Row3','R4','Row5']

# %%
df
# Out:
#       C1  C2  C3  C4  C5  C6 Name
# R1    63  39  26  31  39  72    A
# R2    73  50  35  53  44  53    B
# Row3  41  12  76  31  44  10    C
# R4    39  56  47  57  57  41    D
# Row5  62  40  21  12  12  58    E

# %%
df.rename(index={'Row3':'R3','Row5':'R5'},columns={'C1':'Col1','C5':'Col5'},inplace=True)

# %%
df
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    63  39  26  31    39  72    A
# R2    73  50  35  53    44  53    B
# R3    41  12  76  31    44  10    C
# R4    39  56  47  57    57  41    D
# R5    62  40  21  12    12  58    E

# %%
df1 = df.copy()

# %%
df1
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    63  39  26  31    39  72    A
# R2    73  50  35  53    44  53    B
# R3    41  12  76  31    44  10    C
# R4    39  56  47  57    57  41    D
# R5    62  40  21  12    12  58    E

# %%
df1.iloc[[2,4,1],[1,3]] = np.nan

# %%
df1.iloc[2,6] = np.nan

# %%
df1
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name
# R1    63  39.0  26  31.0    39  72    A
# R2    73   NaN  35   NaN    44  53    B
# R3    41   NaN  76   NaN    44  10  NaN
# R4    39  56.0  47  57.0    57  41    D
# R5    62   NaN  21   NaN    12  58    E

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, R1 to R5
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    5 non-null      int32
#  1   C2      5 non-null      int32
#  2   C3      5 non-null      int32
#  3   C4      5 non-null      int32
#  4   Col5    5 non-null      int32
#  5   C6      5 non-null      int32
#  6   Name    5 non-null      object
# dtypes: int32(6), object(1)
# memory usage: 200.0+ bytes

# %%
df1.isna()
# Out:
#      Col1     C2     C3     C4   Col5     C6   Name
# R1  False  False  False  False  False  False  False
# R2  False   True  False   True  False  False  False
# R3  False   True  False   True  False  False   True
# R4  False  False  False  False  False  False  False
# R5  False   True  False   True  False  False  False

# %%
df1.dropna()
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name
# R1    63  39.0  26  31.0    39  72    A
# R4    39  56.0  47  57.0    57  41    D

# %%
df1.dropna(axis=1)
# Out:
#     Col1  C3  Col5  C6
# R1    63  26    39  72
# R2    73  35    44  53
# R3    41  76    44  10
# R4    39  47    57  41
# R5    62  21    12  58

# %%
df1.dropna(how='any')
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name
# R1    63  39.0  26  31.0    39  72    A
# R4    39  56.0  47  57.0    57  41    D

# %%
df1.dropna(how='all')
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name
# R1    63  39.0  26  31.0    39  72    A
# R2    73   NaN  35   NaN    44  53    B
# R3    41   NaN  76   NaN    44  10  NaN
# R4    39  56.0  47  57.0    57  41    D
# R5    62   NaN  21   NaN    12  58    E

# %%
df1['Test'] = [np.nan]*len(df1.index)

# %%
df1
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name  Test
# R1    63  39.0  26  31.0    39  72    A   NaN
# R2    73   NaN  35   NaN    44  53    B   NaN
# R3    41   NaN  76   NaN    44  10  NaN   NaN
# R4    39  56.0  47  57.0    57  41    D   NaN
# R5    62   NaN  21   NaN    12  58    E   NaN

# %%
df1.dropna(how='all',axis=1)
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name
# R1    63  39.0  26  31.0    39  72    A
# R2    73   NaN  35   NaN    44  53    B
# R3    41   NaN  76   NaN    44  10  NaN
# R4    39  56.0  47  57.0    57  41    D
# R5    62   NaN  21   NaN    12  58    E

# %%
df1['C2'].fillna(df['C2'].mean(),inplace=True)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_61264\1368034232.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['C2'].fillna(df['C2'].mean(),inplace=True)

# %%
df1
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name  Test
# R1    63  39.0  26  31.0    39  72    A   NaN
# R2    73  39.4  35   NaN    44  53    B   NaN
# R3    41  39.4  76   NaN    44  10  NaN   NaN
# R4    39  56.0  47  57.0    57  41    D   NaN
# R5    62  39.4  21   NaN    12  58    E   NaN

# %%
df1.fillna(df)
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name  Test
# R1    63  39.0  26  31.0    39  72    A   NaN
# R2    73  39.4  35  53.0    44  53    B   NaN
# R3    41  39.4  76  31.0    44  10    C   NaN
# R4    39  56.0  47  57.0    57  41    D   NaN
# R5    62  39.4  21  12.0    12  58    E   NaN

# %%
df1
# Out:
#     Col1    C2  C3    C4  Col5  C6 Name  Test
# R1    63  39.0  26  31.0    39  72    A   NaN
# R2    73  39.4  35   NaN    44  53    B   NaN
# R3    41  39.4  76   NaN    44  10  NaN   NaN
# R4    39  56.0  47  57.0    57  41    D   NaN
# R5    62  39.4  21   NaN    12  58    E   NaN

# %%
df1.fillna(method='ffill',limit=2)
# Out:
# C:\Users\BSRVPrasad\AppData\Local\Temp\ipykernel_61264\3521651076.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1.fillna(method='ffill',limit=2)
#     Col1    C2  C3    C4  Col5  C6 Name  Test
# R1    63  39.0  26  31.0    39  72    A   NaN
# R2    73  39.4  35  31.0    44  53    B   NaN
# R3    41  39.4  76  31.0    44  10    B   NaN
# R4    39  56.0  47  57.0    57  41    D   NaN
# R5    62  39.4  21  57.0    12  58    E   NaN

# %%
df
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    63  39  26  31    39  72    A
# R2    73  50  35  53    44  53    B
# R3    41  12  76  31    44  10    C
# R4    39  56  47  57    57  41    D
# R5    62  40  21  12    12  58    E

# %%
df.to_csv('DF.txt',sep='\t')

# %%
df.to_excel('DF.xlsx',sheet_name='Data')

# %%
dfn = pd.read_csv('DF.txt',sep='\t',index_col=0,skiprows=0)
dfn
# Out:
#     Col1  C2  C3  C4  Col5  C6 Name
# R1    63  39  26  31    39  72    A
# R2    73  50  35  53    44  53    B
# R3    41  12  76  31    44  10    C
# R4    39  56  47  57    57  41    D
# R5    62  40  21  12    12  58    E

# %%
dfe = pd.read_excel('DF.xlsx',index_col=0)
dfe
# Out:
# 35      36  3.25  1.250  29.0      35.3       5.88   6.66  8.13    9.400
#
#     NH4-N  NO2-N  NO3-N  PO4-P  SiO2-Si    TN     TP
# 0     1.5   0.45   4.20   6.30     1.50   NaN    NaN
# 1     9.9   0.39   1.04   4.50     8.00  19.1  11.60
# 2    11.2   0.30   0.79   6.00    12.00  18.6  11.60
# 3     2.9   0.21   1.07   9.30     9.00  21.1    NaN
# 4     2.3   0.41   1.09   6.60     8.00  29.1  10.80
# 5    12.6   0.41   1.28   2.57    10.80  30.0    NaN
# 6     3.5   0.35   4.90   1.93    22.20  25.0   2.20
# 7     4.8   0.46  13.90   1.82    54.40  21.0   1.10
# 8     NaN    NaN    NaN    NaN      NaN   NaN    NaN
# 9     4.2   0.63  11.59   4.09    44.90   NaN    NaN
# 10    6.6   0.40   5.78   0.96    16.20  11.4   1.59
# 11    4.7   0.44   6.09   3.00    49.10  21.0   1.10
# 12    9.6   0.58   4.90   1.98    45.18   NaN    NaN
# 13    8.2   0.49  16.53   1.17    15.03   2.0    NaN
# 14    0.2   0.15   0.79   0.56    19.80   1.0   6.40
# 15    2.2   0.24   1.35   0.50    22.50   5.1  17.40
# 16    0.2   0.18   1.17   0.39    22.80   2.8   2.60
# 17    2.8   1.00   0.93   1.80     7.00  15.8   6.80
# 18    2.5   0.14   0.88   0.48    11.70   3.6   4.80
# 19    2.0   1.13   0.55   0.41    20.00   4.6   4.50
# 20    0.2   0.10   0.89   0.29    20.70  32.0   2.20
# 21    1.6   1.74   1.27   2.60    19.90   NaN   2.90
# 22    0.5   0.23   1.24   6.90    27.90   2.5    NaN
# 23    0.3   0.19   1.39   3.00    26.30   5.7   3.30
# 24    0.8   0.36   1.19   3.70    21.70  18.8   3.80
# 25    0.8   1.93   1.59   2.90    35.70   8.4    NaN
# 26    0.9   1.10   9.10   1.70    80.00   7.4    NaN
# 27    0.8   0.17   0.77   3.00    14.90  12.5   4.30
# 28    1.2   0.10   0.69   2.70    12.80   4.8    NaN
# 29    3.6   0.52   2.50   2.60    12.00   7.7    NaN
# 30    0.8   1.30   4.30   1.60     3.90  11.6    NaN
# 31    1.4   0.30   1.30   3.70    32.00   8.0    NaN
# 32    0.8   0.40   3.30   3.04    32.00   8.3    NaN
# 33    5.0   0.20   1.08   0.40     4.30  19.8   1.70
# 34    5.1   0.30   1.10   0.50     6.60  24.8   1.90
# 35    4.1   0.18   0.40   0.60     6.80  15.8  11.40

# %%
DataAug04 = pd.read_excel('WQ.xlsx',sheet_name='Aug 04')

# %%
DataAug04
# Out:
#     St. No  Depth   S.D   W.T  Salinity  Turbidity     DO    pH     TSM  \
# 0        1   0.85  0.85  33.6     18.50       3.46   7.50  8.10   18.75
# 1        2   2.25  0.75  33.0     21.20       8.27   5.60  8.30   25.82
# 2        3   3.00  0.75  33.3     24.50       7.80   8.00  8.10   19.28
# 3        4   2.25  1.75  32.9     22.30       2.62   8.00  8.30   16.94
# 4        5   2.00  2.00  32.0     19.00       1.07   9.10  8.30   15.62
# std    10.535654   0.821666   0.518994   1.553245   9.980345   60.686398
# min     1.000000   0.500000   0.000000  29.600000   0.000000    0.280000
# 25%     9.750000   1.250000   0.100000  30.900000   0.175000    4.682500
# 50%    18.500000   1.750000   0.500000  31.900000   6.700000    8.605000
# 75%    27.250000   2.312500   0.750000  33.150000  20.250000   55.325000
# max    36.000000   3.500000   2.000000  36.000000  27.180000  210.000000
#
#               DO         pH         TSM      NH4-N      NO2-N      NO3-N  \
# count  36.000000  36.000000   36.000000  36.000000  36.000000  36.000000
# mean    8.313889   8.097778   58.284167   3.951383   0.291049   1.862920
# std     1.724218   0.305110   60.725918   4.244403   0.179676   2.407828
# min     3.000000   7.100000   12.780000   0.000000   0.040980   0.231660
# 25%     7.425000   8.000000   17.787500   1.219612   0.163920   0.657322
# 50%     8.450000   8.100000   27.010000   2.623145   0.228745   0.918000
# 75%     9.225000   8.300000   75.377500   5.544992   0.438400   1.899247
# max    12.000000   8.700000  252.000000  22.117140   0.908800  11.043130
#
#            PO4-P    SiO2-Si          TN         TP
# count  36.000000  35.000000   36.000000  36.000000
# mean    0.363444  24.554043   38.219726   1.646746
# std     0.260552  23.027126   21.798009   1.148325
# min     0.010520   0.840200   11.725000   0.214000
# 25%     0.150750   4.777500   25.397700   0.611995
# 50%     0.267260  16.120000   33.231075   1.493840
# 75%     0.578930  36.700000   46.857600   2.577195
# max     0.948200  81.499400  111.087550   5.198200

# %%
DataAug04.plot()
# Out:
# <Axes: >

# %%
DataAug04.plot(subplots=True,figsize=(8,30))
plt.show()

# %%
DataAug04.columns
# Out:
# Index(['St. No', 'Depth', 'S.D', 'W.T', 'Salinity', 'Turbidity', 'DO', 'pH',
#        'TSM', 'NH4-N', 'NO2-N', 'NO3-N', 'PO4-P', 'SiO2-Si', 'TN', 'TP'],
#       dtype='object')

# %%
DataAug04.plot(x='St. No',y='Depth',kind='scatter')
# Out:
# <Axes: xlabel='St. No', ylabel='Depth'>

# %%
DataAug04['Depth'].plot.bar(figsize=(8,3),xlabel='St. No',ylabel='Depth',\
                           title='Plot of Depth as Bar Chart')
# Out:
# <Axes: title={'center': 'Plot of Depth as Bar Chart'}, xlabel='St. No', ylabel='Depth'>

# %%
DataAug04[['Depth','DO']].plot.pie(subplots=True,legend=False)
# Out:
# array([<Axes: ylabel='Depth'>, <Axes: ylabel='DO'>], dtype=object)

# %%
[method_name for method_name in dir(DataAug04.plot) \
 if not method_name.startswith("_")]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
DataAug04.plot(kind='kde',figsize=(8,30),subplots=True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#        <Axes: ylabel='Density'>, <Axes: ylabel='Density'>], dtype=object)

# %%
DataAug04[['Depth','DO']].plot(kind='area',legend=True)
plt.show()

# %%
DataAug04.plot(kind='line',legend=True)
plt.legend(bbox_to_anchor=(1, 0),loc='lower left')
plt.show()

# %%
exl = pd.ExcelFile('WQ.xlsx')

# %%
exl.sheet_names
# Out:
# ['May 04',
#  'June 04',
#  'July 04',
#  'Aug 04',
#  'Sep 04',
#  'Oct 04',
#  'Nov 04',
#  'Dec 04',
#  'Jan 05',
#  'Feb 05',
#  'Mar 05',
#  'Apr 05',
#  'May 05',
#  'June 05',
#  'July 05',
#  'Aug 05',
#  'Sep 05',
#  'Oct 05',
#  'Nov 05',
#  'Dec 05',
#  'Jan 06',
#  'Feb 06',
#  'Mar 06',
#  'Apr 06',
#  'May 06',
#  'June 06',
#  'July 06',
#  'Aug 06',
#  'Sep 06']

# %%
exl = pd.ExcelFile('WQ.xlsx')
Data = pd.DataFrame()
for sheet in exl.sheet_names:
    temp = pd.read_excel('WQ.xlsx',sheet_name = sheet)
    Data = pd.concat([Data,temp])

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1044 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   St. No     1044 non-null   int64
#  1   Depth      1034 non-null   object
#  2   S.D        1033 non-null   float64
#  3   W.T        1035 non-null   float64
#  4   Salinity   1035 non-null   float64
#  5   Turbidity  1030 non-null   float64
#  6   DO         1035 non-null   float64
#  7   pH         1036 non-null   float64
#  8   TSM        1026 non-null   float64
#  9   NH4-N      1026 non-null   float64
#  10  NO2-N      1036 non-null   float64
#  11  NO3-N      1031 non-null   float64
#  12  PO4-P      1035 non-null   float64
#  13  SiO2-Si    1033 non-null   float64
#  14  TN         1027 non-null   float64
#  15  TP         1012 non-null   float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 138.7+ KB

# %%
Data.loc[1]
# Out:
#    St. No Depth   S.D   W.T  Salinity  Turbidity    DO     pH     TSM  \
# 1       2  2.25  0.50  30.0    10.400      16.00  6.90  8.270   23.20
# 1       2  2.25  0.25  29.5    19.100      58.70  7.10  8.080   69.88
# 1       2   2.3  0.00  30.6    22.200     108.00  6.60  8.140  159.80
# 1       2  2.25  0.75  33.0    21.200       8.27  5.60  8.300   25.82
# 1       2  2.25  0.50  31.5    19.500      23.00  7.30  8.380   16.20
# 1       2  2.65  1.75  30.0    12.500       7.71  6.40  8.400   16.40
# 1       2  2.25  1.00  26.6    15.900       2.80  6.58  8.450   10.80
# 1       2  2.35  0.75  25.5    15.480       8.89  9.34  8.650   24.00
# 1       2  2.25  1.00  25.5    16.640       7.22  6.75  8.310   29.00
# 1       2   2.0  1.00  29.5    22.400       3.20  8.22  8.580   20.00
# 1       2  1.85  0.00  30.5    18.400     151.00  6.45  8.210  210.00
# 1       2  2.75  0.10  31.5    21.700      58.50  6.45  8.090   84.50
# 1       2   NaN  0.00  28.0    27.000      54.00  8.44  7.948  145.44
# 1       2  2.75  0.25  30.0    30.720      15.00  9.01  8.220  127.30
# 1       2   2.5  0.75  31.5    25.100      16.10  7.08  8.110   48.00
# 1       2  2.75  1.00  32.9    24.510       2.81  6.12  8.260   38.08
# 1       2   2.5  1.00  32.5    13.700       0.14  7.48  8.640   15.40
# 1       2   3.0  0.75  29.3    11.770       5.77  7.57  8.630   26.00
# 1       2   2.5  1.00  25.5    10.360       6.10  7.89  8.690   26.00
# 1       2   2.5  1.25  24.2     9.530       3.80  8.27  8.510   10.20
